# %%
2+2
# Out:
# 4

# %%
import sys
sys.path.append('/Users/dishant/Downloads/Code/GenAI/Projects/AgentFromScratch')

# %%
from MultiAgent.Crew import Crew

# %%
from MultiAgent.Agent import Agent

# %%
from ToolAgent.tool import tool

# %%
@tool
def write_str_to_txt(string_data: str, txt_filename: str):
    """
    Writes a string to a txt file.

    This function takes a string and writes it to a text file. If the file already exists, 
    it will be overwritten with the new data.

    Args:
        string_data (str): The string containing the data to be written to the file.
        txt_filename (str): The name of the text file to which the data should be written.
    """
    # Write the string data to the text file
    with open(txt_filename, mode='w', encoding='utf-8') as file:
        file.write(string_data)

    print(f"Data successfully written to {txt_filename}")

# %%
with Crew() as crew:
    agent_1 = Agent(
        name="Poet Agent",
        backstory="You are a well-known poet, who enjoys creating high quality poetry.",
        taskDescription="Write a poem about the meaning of life",
        taskExpectedOutput="Just output the poem, without any title or introductory sentences",
    )

    agent_2 = Agent(
        name="Poem Translator Agent",
        backstory="You are an expert translator especially skilled in Spanish",
        taskDescription="Translate a poem into Spanish", 
        taskExpectedOutput="Just output the translated poem and nothing else"
    )

    agent_3 = Agent(
        name="Writer Agent",
        backstory="You are an expert transcriber, that loves writing poems into txt files",
        taskDescription="You'll receive a Spanish poem in your context. You need to write the poem into './poem.txt' file",
        taskExpectedOutput="A txt file containing the greek poem received from the context",
        tools=write_str_to_txt,
    )

    agent_1 >> agent_2 >> agent_3

# %%
crew.plot()

# %%
crew.run()
# Out:
# ...
# RUNNING AGENT: Poet Agent : You are a well-known poet, who enjoys creating high quality poetry.
# ...
#
# In the grand tapestry of existence, we're a thread,
# A fleeting moment, a whisper, a breath.
# Our lives a dance of purpose, a search for the why,
# A journey through the labyrinth of time.
#
# We seek the meaning in every sunrise high,
# In every star that twinkles in the evening sky.
# We find it in the laughter of children at play,
# In the warmth of love that never fades away.
#
# It's in the beauty of nature, wild and free,
# A reflection of the beauty that's meant to be.
# In the depths of our souls, a spark is lit,
# A flame that flickers, guiding us through life's pit.
#
# The meaning of life is a mystery we unwind,
# A puzzle we solve, one piece at a time.
# It's in the moments we share, the love we create,
# The memories we make, the legacy we participate.
#
# In the end, it's not the years we live that matter,
# But the life we live in those years, the love we scatter.
# ...
