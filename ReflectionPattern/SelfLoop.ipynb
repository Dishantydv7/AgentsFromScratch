# %%
2+1
# Out:
# 3

# %%
import sys
sys.path.append('/Users/dishant/Downloads/Code/GenAI/Projects/AgentFromScratch')

# %%
from classesScratch.selfLoop import ReflectionAgent

# %%
agent = ReflectionAgent()

# %%
generation_system_prompt = "You are a singer asked to make a song about the beauty of nature"

reflection_system_prompt = "You are Honey Singh , a well known singer"

user_msg = "Generate a song on nature"

# %%
response = agent.run(userMsg=user_msg,
    generation_system_prompt=generation_system_prompt,
    reflection_system_prompt=reflection_system_prompt,
    nSteps=5,
    verbose=1)
# Out:
# ...
# STEP 1/5
# ...
#
#
#
# GENERATION
#
#  **Title:** "Echoes of the Earth"
#
# **Verse 1:**
# In the whispering woods, where trees preside
# A gentle breeze awakens, side by side
# The sun rises high, a fiery glow
# Painting the horizon, as the morning grows
#
# **Chorus:**
# Oh, the beauty of nature, it calls to me
# A symphony of wonder, wild and free
# From the mountains high to the oceans wide
# I'm drawn to the magic, where love resides
#
# **Verse 2:**
# In the forest depths, a river flows
# A serenade of silence, as the water glows
# The creatures of the wild, they sing and sway
# A chorus of joy, on this earthly day
#
# **Chorus:**
# Oh, the beauty of nature, it calls to me
# A symphony of wonder, wild and free
# From the mountains high to the oceans wide
# I'm drawn to the magic, where love resides
#
# **Bridge:**
# As the stars appear, in the evening sky
# A celestial showcase, as the world goes by
# The moon's soft light, illuminates the night
# ...
