# %%
2+1
# Out:
# 3

# %%
import sys
sys.path.append('/Users/dishant/Downloads/Code/GenAI/Projects/AgentFromScratch')

# %%
from SelfLoopClass.selfLoop import ReflectionAgent

# %%
agent = ReflectionAgent()

# %%
generation_system_prompt = "You are a writer asked to make a song about the beauty of nature"

reflection_system_prompt = "You are chetan bhagat, a well known writer"

user_msg = "Write a song on nature"

# %%
response = agent.run(userMsg=user_msg,
    generation_system_prompt=generation_system_prompt,
    reflection_system_prompt=reflection_system_prompt,
    nSteps=5,
    verbose=1)
# Out:
# ...
# STEP 1/5
# ...
#
#
#
# GENERATION
#
#  **Title:** "Harmony of the Earth"
#
# **Verse 1:**
# In the forest, where the trees preside
# A gentle breeze whispers, side by side
# The rustling leaves, a soothing sound
# As nature awakens, all around
# The sun rises high, a fiery ball
# Painting the sky, with colors of all
# The dew drops glisten, like diamonds bright
# A new day begins, in the morning light
#
# **Chorus:**
# Oh, the beauty of nature, it never fades
# A symphony of wonder, in every shade
# From the mountains high, to the oceans wide
# The harmony of the earth, is where I reside
#
# **Verse 2:**
# The river flows, like a winding stream
# Reflecting the sky, in a perfect dream
# The flowers bloom, in a vibrant display
# A colorful tapestry, in a sunny day
# The birds sing sweet, their melodies so free
# A chorus of joy, in perfect harmony
# The wind whispers secrets, through the trees so tall
# A mystery of wonder, that enthralls us all
#
# **Chorus:**
# ...
